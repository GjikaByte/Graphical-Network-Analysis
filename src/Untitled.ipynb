# %%
pip install cvxpy
# Out:
# ...
#   Using cached cvxpy-1.1.7.tar.gz (1.0 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached osqp-0.6.1-cp38-cp38-macosx_10_9_x86_64.whl (158 kB)
# ...
#   Using cached scs-2.1.2.tar.gz (3.5 MB)
# ...
#   Using cached ecos-2.0.7.post1.tar.gz (126 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Users/andigjika/opt/anaconda3/bin/python /Users/andigjika/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/6n/352_6wm12hz6zcnf7766mxr00000gn/T/tmpxu6xs7na
#        cwd: /private/var/folders/6n/352_6wm12hz6zcnf7766mxr00000gn/T/pip-install-tpacnyuh/cvxpy
#   Complete output (418 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.8
#   creating build/lib.macosx-10.9-x86_64-3.8/cvxpy
#   copying cvxpy/error.py -> build/lib.macosx-10.9-x86_64-3.8/cvxpy
# ...

# %%
#pip install pytest
pytest cvxpy/tests
# Out:
#   File "<ipython-input-3-cd751a74e0a6>", line 2
#     pytest cvxpy/tests
#            ^
# SyntaxError: invalid syntax
